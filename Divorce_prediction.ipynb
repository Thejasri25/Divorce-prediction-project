# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score, classification_report, plot_roc_curve, confusion_matrix, ConfusionMatrixDisplay

# %%
df = pd.read_csv("C:/Users/91960/Downloads/divorce_data (1).csv", sep = ';')
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q46  Q47  Q48  Q49  Q50  Q51  \
# 0   2   2   4   1   0   0   0   0   0    0  ...    2    1    3    3    3    2
# 1   4   4   4   4   4   0   0   4   4    4  ...    2    2    3    4    4    4
# 2   2   2   2   2   1   3   2   1   1    2  ...    3    2    3    1    1    1
# 3   3   2   3   2   3   3   3   3   3    3  ...    2    2    3    3    3    3
# 4   2   2   1   1   1   1   0   0   0    0  ...    2    1    2    3    2    2
#
#    Q52  Q53  Q54  Divorce
# 0    3    2    1        1
# 1    4    2    2        1
# 2    2    2    2        1
# 3    2    2    2        1
# 4    2    1    0        1
#
# [5 rows x 55 columns]

# %%
sns.countplot(x = df['Divorce'])
# Out:
# <AxesSubplot:xlabel='Divorce', ylabel='count'>

# %%
corr = df.corr()
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_precision(2)
# Out:
# <style type="text/css">
# #T_89a66_row0_col0, #T_89a66_row1_col1, #T_89a66_row2_col2, #T_89a66_row3_col3, #T_89a66_row4_col4, #T_89a66_row5_col5, #T_89a66_row6_col6, #T_89a66_row7_col7, #T_89a66_row8_col8, #T_89a66_row9_col9, #T_89a66_row10_col10, #T_89a66_row11_col11, #T_89a66_row12_col12, #T_89a66_row13_col13, #T_89a66_row14_col14, #T_89a66_row15_col15, #T_89a66_row16_col16, #T_89a66_row17_col17, #T_89a66_row18_col18, #T_89a66_row19_col19, #T_89a66_row20_col20, #T_89a66_row21_col21, #T_89a66_row22_col22, #T_89a66_row23_col23, #T_89a66_row24_col24, #T_89a66_row25_col25, #T_89a66_row26_col26, #T_89a66_row27_col27, #T_89a66_row28_col28, #T_89a66_row29_col29, #T_89a66_row30_col30, #T_89a66_row31_col31, #T_89a66_row32_col32, #T_89a66_row33_col33, #T_89a66_row34_col34, #T_89a66_row35_col35, #T_89a66_row36_col36, #T_89a66_row37_col37, #T_89a66_row38_col38, #T_89a66_row39_col39, #T_89a66_row40_col40, #T_89a66_row41_col41, #T_89a66_row42_col42, #T_89a66_row43_col43, #T_89a66_row44_col44, #T_89a66_row45_col45, #T_89a66_row46_col46, #T_89a66_row47_col47, #T_89a66_row48_col48, #T_89a66_row49_col49, #T_89a66_row50_col50, #T_89a66_row51_col51, #T_89a66_row52_col52, #T_89a66_row53_col53, #T_89a66_row54_col54 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_89a66_row0_col1, #T_89a66_row1_col22, #T_89a66_row3_col11, #T_89a66_row3_col14, #T_89a66_row3_col35, #T_89a66_row4_col9, #T_89a66_row11_col35, #T_89a66_row12_col34, #T_89a66_row14_col40, #T_89a66_row16_col9, #T_89a66_row16_col21, #T_89a66_row17_col43, #T_89a66_row20_col0, #T_89a66_row21_col33, #T_89a66_row23_col9, #T_89a66_row23_col12, #T_89a66_row24_col0, #T_89a66_row25_col12, #T_89a66_row26_col43, #T_89a66_row27_col32, #T_89a66_row28_col33, #T_89a66_row30_col39, #T_89a66_row31_col40, #T_89a66_row31_col54, #T_89a66_row37_col15, #T_89a66_row40_col27, #T_89a66_row43_col22 {
#   background-color: #9bb6d7;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_89a66_row0_col2, #T_89a66_row0_col15, #T_89a66_row1_col38, #T_89a66_row1_col39, #T_89a66_row3_col2, #T_89a66_row3_col10, #T_89a66_row4_col23, #T_89a66_row7_col53, #T_89a66_row12_col26, #T_89a66_row12_col35, #T_89a66_row13_col0, #T_89a66_row13_col22, #T_89a66_row13_col40, #T_89a66_row15_col13, #T_89a66_row16_col23, #T_89a66_row16_col36, #T_89a66_row17_col22, #T_89a66_row17_col32, #T_89a66
# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Divorce', axis=1),
                                                   df['Divorce'],
                                                   test_size = 0.5,
                                                   random_state=42)

# %%
model_svm = SVC(random_state=42).fit(x_train, y_train)

y_pred_svm = model_svm.predict(x_test)

# %%
model_kn = KNeighborsClassifier().fit(x_train, y_train)

y_pred_kn = model_kn.predict(x_test)

# %%
model_lr = LogisticRegression().fit(x_train, y_train)

y_pred_lr = model_lr.predict(x_test)

# %%
model_rf = RandomForestClassifier(random_state=42).fit(x_train, y_train)

y_pred_rf = model_rf.predict(x_test)

# %%
model_gb = GradientBoostingClassifier(random_state=42).fit(x_train, y_train)

y_pred_gb = model_gb.predict(x_test)

# %%
model_dt = DecisionTreeClassifier(random_state=42).fit(x_train, y_train)

y_pred_dt = model_dt.predict(x_test)

# %%
print('Accuracy score SVM: {:.4f}' .format(accuracy_score(y_test, y_pred_svm)))
print('Accuracy score KN:  {:.4f}' .format(accuracy_score(y_test, y_pred_kn)))
print('Accuracy score LR:  {:.4f}' .format(accuracy_score(y_test, y_pred_lr)))
print('Accuracy score RF:  {:.4f}' .format(accuracy_score(y_test, y_pred_rf)))
print('Accuracy score GB:  {:.4f}' .format(accuracy_score(y_test, y_pred_gb)))
print('Accuracy score DT:  {:.4f}' .format(accuracy_score(y_test, y_pred_dt)))
# Out:
# Accuracy score SVM: 0.9647
# Accuracy score KN:  0.9647
# Accuracy score LR:  0.9647
# Accuracy score RF:  0.9647
# Accuracy score GB:  0.9647
# Accuracy score DT:  0.9176

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        39
#            1       1.00      0.93      0.97        46
#
#     accuracy                           0.96        85
#    macro avg       0.96      0.97      0.96        85
# weighted avg       0.97      0.96      0.96        85

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        39
#            1       1.00      0.93      0.97        46
#
#     accuracy                           0.96        85
#    macro avg       0.96      0.97      0.96        85
# weighted avg       0.97      0.96      0.96        85

# %%
print(classification_report(y_test, y_pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        39
#            1       1.00      0.93      0.97        46
#
#     accuracy                           0.96        85
#    macro avg       0.96      0.97      0.96        85
# weighted avg       0.97      0.96      0.96        85

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        39
#            1       1.00      0.93      0.97        46
#
#     accuracy                           0.96        85
#    macro avg       0.96      0.97      0.96        85
# weighted avg       0.97      0.96      0.96        85

# %%
print(classification_report(y_test, y_pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        39
#            1       1.00      0.93      0.97        46
#
#     accuracy                           0.96        85
#    macro avg       0.96      0.97      0.96        85
# weighted avg       0.97      0.96      0.96        85

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91        39
#            1       0.95      0.89      0.92        46
#
#     accuracy                           0.92        85
#    macro avg       0.92      0.92      0.92        85
# weighted avg       0.92      0.92      0.92        85

# %%
plot_roc_curve(model_lr, x_test, y_test)

# %%
plot_roc_curve(model_svm, x_test, y_test)

# %%
plot_roc_curve(model_kn, x_test, y_test)

# %%
plot_roc_curve(model_rf, x_test, y_test)

# %%
plot_roc_curve(model_gb, x_test, y_test)

# %%
plot_roc_curve(model_dt, x_test, y_test)

# %%
predictions = model_lr.predict(x_test)
cm = confusion_matrix(y_test, y_pred_lr, labels = model_lr.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model_lr.classes_)
disp.plot()
plt.show()

# %%
predictions = model_svm.predict(x_test)
cm = confusion_matrix(y_test, y_pred_svm, labels = model_svm.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model_svm.classes_)
disp.plot()
plt.show()

# %%
predictions = model_kn.predict(x_test)
cm = confusion_matrix(y_test, y_pred_kn, labels = model_kn.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model_kn.classes_) 
disp.plot()
plt.show()

# %%
predictions = model_rf.predict(x_test)
cm = confusion_matrix(y_test, y_pred_rf, labels = model_rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model_rf.classes_)
disp.plot()
plt.show()

# %%
predictions = model_gb.predict(x_test)
cm = confusion_matrix(y_test, y_pred_lr, labels = model_gb.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model_gb.classes_)
disp.plot()
plt.show()

# %%
predictions = model_dt.predict(x_test)
cm = confusion_matrix(y_test, y_pred_dt, labels = model_dt.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = model_dt.classes_)
disp.plot()
plt.show()
